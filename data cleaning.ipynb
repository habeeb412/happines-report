# %%
import  pandas as pd

# %%
df=pd.read_csv("world-happiness-report - world-happiness-report.csv")

# %%
df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df.tail()
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1944                              54.4                         0.733
# 1945                              55.0                         0.753
# 1946                              55.6                         0.763
# 1947                              56.2                         0.632
# 1948                              56.8                         0.643
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df.shape
# Out:
# (1949, 11)

# %%
df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
df.sample(8)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1896      Vietnam  2008        5.480               8.440           0.805
# 1548     Slovenia  2010        6.083              10.419           0.917
# 954        Latvia  2006        4.710              10.032           0.884
# 1304       Norway  2015        7.603              11.033           0.947
# 950          Laos  2017        4.623               8.890           0.707
# 1012    Lithuania  2017        6.273              10.429           0.926
# 719       Hungary  2016        5.449              10.248           0.900
# 1623    Sri Lanka  2014        4.268               9.344           0.805
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1896                             66.18                         0.889
# 1548                             69.20                         0.896
# 954                              63.16                         0.641
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("world-happiness-report - world-happiness-report.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   object
#  1   year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Positive affect                   1927 non-null   float64
#  10  Negative affect                   1933 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
df.dtypes
# Out:
# Country name                         object
# year                                  int64
# Life Ladder                         float64
# Log GDP per capita                  float64
# Social support                      float64
# Healthy life expectancy at birth    float64
# Freedom to make life choices        float64
# Generosity                          float64
# Perceptions of corruption           float64
# Positive affect                     float64
# Negative affect                     float64
# dtype: object

# %%
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1949.000000  1949.000000         1913.000000     1936.000000
# mean   2013.216008     5.466705            9.368453        0.812552
# std       4.166828     1.115711            1.154084        0.118482
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.640000            8.464000        0.749750
# 50%    2013.000000     5.386000            9.460000        0.835500
# 75%    2017.000000     6.283000           10.353000        0.905000
# max    2020.000000     8.019000           11.648000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359374                      0.742558
# std                            7.510245                      0.142093
# min                           32.300000                      0.258000
# ...

# %%
df

# %%
df.columns=df.columns.str.strip().str.lower().str.replace(" ","_")
df.columns
# Out:
# Index(['country_name', 'year', 'life_ladder', 'log_gdp_per_capita',
#        'social_support', 'healthy_life_expectancy_at_birth',
#        'freedom_to_make_life_choices', 'generosity',
#        'perceptions_of_corruption', 'positive_affect', 'negative_affect'],
#       dtype='object')

# %%
df
# Out:
#      _c_o_u_n_t_r_y_ _n_a_m_e_  _y_e_a_r_  _l_i_f_e_ _l_a_d_d_e_r_  \
# 0                  Afghanistan       2008                    3.724
# 1                  Afghanistan       2009                    4.402
# 2                  Afghanistan       2010                    4.758
# 3                  Afghanistan       2011                    3.832
# 4                  Afghanistan       2012                    3.783
# ...                        ...        ...                      ...
# 1944                  Zimbabwe       2016                    3.735
# 1945                  Zimbabwe       2017                    3.638
# 1946                  Zimbabwe       2018                    3.616
# 1947                  Zimbabwe       2019                    2.694
# 1948                  Zimbabwe       2020                    3.160
#
#       _l_o_g_ _g_d_p_ _p_e_r_ _c_a_p_i_t_a_  _s_o_c_i_a_l_ _s_u_p_p_o_r_t_  \
# 0                                     7.370                          0.451
# ...

# %%
df.isnull()
# Out:
#       _c_o_u_n_t_r_y_ _n_a_m_e_  _y_e_a_r_  _l_i_f_e_ _l_a_d_d_e_r_  \
# 0                         False      False                    False
# 1                         False      False                    False
# 2                         False      False                    False
# 3                         False      False                    False
# 4                         False      False                    False
# ...                         ...        ...                      ...
# 1944                      False      False                    False
# 1945                      False      False                    False
# 1946                      False      False                    False
# 1947                      False      False                    False
# 1948                      False      False                    False
#
#       _l_o_g_ _g_d_p_ _p_e_r_ _c_a_p_i_t_a_  _s_o_c_i_a_l_ _s_u_p_p_o_r_t_  \
# ...

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   36
# Social support                       13
# Healthy life expectancy at birth     55
# Freedom to make life choices         32
# Generosity                           89
# Perceptions of corruption           110
# Positive affect                      22
# Negative affect                      16
# dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#      _c_o_u_n_t_r_y_ _n_a_m_e_  _y_e_a_r_  _l_i_f_e_ _l_a_d_d_e_r_  \
# 0                  Afghanistan       2008                    3.724
# 1                  Afghanistan       2009                    4.402
# 2                  Afghanistan       2010                    4.758
# 3                  Afghanistan       2011                    3.832
# 4                  Afghanistan       2012                    3.783
# ...                        ...        ...                      ...
# 1944                  Zimbabwe       2016                    3.735
# 1945                  Zimbabwe       2017                    3.638
# 1946                  Zimbabwe       2018                    3.616
# 1947                  Zimbabwe       2019                    2.694
# 1948                  Zimbabwe       2020                    3.160
#
#       _l_o_g_ _g_d_p_ _p_e_r_ _c_a_p_i_t_a_  _s_o_c_i_a_l_ _s_u_p_p_o_r_t_  \
# 0                                     7.370                          0.451
# ...

# %%
important_cols = [
    'life_ladder',
    'log_gdp_per_capita',
    'social_support',
    'healthy_life_expectancy_at_birth',
    'freedom_to_make_life_choices'
]

for col in important_cols:
    df[col] = df[col].fillna(df[col].mean())

# %%
df.isnull().sum()
# Out:
# country_name                          0
# year                                  0
# life_ladder                           0
# log_gdp_per_capita                    0
# social_support                        0
# healthy_life_expectancy_at_birth      0
# freedom_to_make_life_choices          0
# generosity                           89
# perceptions_of_corruption           110
# positive_affect                      22
# negative_affect                      16
# dtype: int64

# %%
df['generosity'] = df['generosity'].fillna(df['generosity'].mean())
df['perceptions_of_corruption'] = df['perceptions_of_corruption'].fillna(df['perceptions_of_corruption'].mean())

# %%
df=df.dropna()

# %%
df
# Out:
#      country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("world-happiness-report - world-happiness-report.csv")

# %%
df.isnull().sum()
# Out:
# country_name                        0
# year                                0
# life_ladder                         0
# log_gdp_per_capita                  0
# social_support                      0
# healthy_life_expectancy_at_birth    0
# freedom_to_make_life_choices        0
# generosity                          0
# perceptions_of_corruption           0
# positive_affect                     0
# negative_affect                     0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.groupby('country_name')['life_ladder'].mean()
# Out:
# country_name
# Afghanistan    3.594667
# Albania        5.019385
# Algeria        5.191800
# Angola         4.420250
# Argentina      6.310133
#                  ...
# Venezuela      6.303083
# Vietnam        5.358727
# Yemen          3.969200
# Zambia         4.551714
# Zimbabwe       3.882600
# Name: life_ladder, Length: 157, dtype: float64

# %%
df.groupby('country_name').size()
# Out:
# country_name
# Afghanistan    12
# Albania        13
# Algeria         5
# Angola          4
# Argentina      15
#                ..
# Venezuela      12
# Vietnam        11
# Yemen          10
# Zambia         14
# Zimbabwe       15
# Length: 157, dtype: int64

# %%
df.groupby('country_name')['life_ladder'].agg(['mean', 'min', 'max'])
# Out:
#                   mean    min    max
# country_name
# Afghanistan   3.594667  2.375  4.758
# Albania       5.019385  4.511  5.867
# Algeria       5.191800  4.745  5.605
# Angola        4.420250  3.795  5.589
# Argentina     6.310133  5.793  6.776
# ...                ...    ...    ...
# Venezuela     6.303083  4.041  7.478
# Vietnam       5.358727  5.023  5.767
# Yemen         3.969200  2.983  4.809
# Zambia        4.551714  3.307  5.260
# Zimbabwe      3.882600  2.694  4.955
#
# [157 rows x 3 columns]

# %%
df.groupby(['country_name', 'year'])['life_ladder'].mean().reset_index()
# Out:
#      country_name  year  life_ladder
# 0     Afghanistan  2008        3.724
# 1     Afghanistan  2009        4.402
# 2     Afghanistan  2010        4.758
# 3     Afghanistan  2011        3.832
# 4     Afghanistan  2012        3.783
# ...           ...   ...          ...
# 1822     Zimbabwe  2016        3.735
# 1823     Zimbabwe  2017        3.638
# 1824     Zimbabwe  2018        3.616
# 1825     Zimbabwe  2019        2.694
# 1826     Zimbabwe  2020        3.160
#
# [1827 rows x 3 columns]

# %%
df.groupby('country_name')['life_ladder'].mean().reset_index()
# Out:
#     country_name  life_ladder
# 0    Afghanistan     3.594667
# 1        Albania     5.019385
# 2        Algeria     5.191800
# 3         Angola     4.420250
# 4      Argentina     6.310133
# ..           ...          ...
# 152    Venezuela     6.303083
# 153      Vietnam     5.358727
# 154        Yemen     3.969200
# 155       Zambia     4.551714
# 156     Zimbabwe     3.882600
#
# [157 rows x 2 columns]

# %%
df.groupby('year')['life_ladder'].mean().reset_index()
# Out:
#     year  life_ladder
# 0   2005     6.553478
# 1   2006     5.238747
# 2   2007     5.397381
# 3   2008     5.431924
# 4   2009     5.454083
# 5   2010     5.511457
# 6   2011     5.416878
# 7   2012     5.449778
# 8   2013     5.380397
# 9   2014     5.382892
# 10  2015     5.406955
# 11  2016     5.413534
# 12  2017     5.476525
# 13  2018     5.532000
# 14  2019     5.592784
# 15  2020     5.874349

# %%
df.groupby('country_name')[['log_gdp_per_capita','life_ladder']].mean()
# Out:
#               log_gdp_per_capita  life_ladder
# country_name
# Afghanistan             7.650833     3.594667
# Albania                 9.384385     5.019385
# Algeria                 9.329400     5.191800
# Angola                  8.990000     4.420250
# Argentina              10.033800     6.310133
# ...                          ...          ...
# Venezuela               9.480083     6.303083
# Vietnam                 8.619273     5.358727
# Yemen                   8.102700     3.969200
# Zambia                  8.066857     4.551714
# Zimbabwe                7.850333     3.882600
#
# [157 rows x 2 columns]

# %%
df=df.dropna()
